# %%
import wscrapper
from scrapconf import MainHUNGARY, OutputHUNGARY
#43

# %%
df = wscrapper.main(1, 43, MainHUNGARY, OutputHUNGARY)
# Out:
# At page 1
#  URL:  https://www.amnesty.org/en/latest/campaigns/page/1
# At page 2
#  URL:  https://www.amnesty.org/en/latest/campaigns/page/2
# At page 3
#  URL:  https://www.amnesty.org/en/latest/campaigns/page/3
# At page 4
#  URL:  https://www.amnesty.org/en/latest/campaigns/page/4
# At page 5
#  URL:  https://www.amnesty.org/en/latest/campaigns/page/5
# At page 6
#  URL:  https://www.amnesty.org/en/latest/campaigns/page/6
# At page 7
#  URL:  https://www.amnesty.org/en/latest/campaigns/page/7
# At page 8
#  URL:  https://www.amnesty.org/en/latest/campaigns/page/8
# At page 9
#  URL:  https://www.amnesty.org/en/latest/campaigns/page/9
# At page 10
#  URL:  https://www.amnesty.org/en/latest/campaigns/page/10
# At page 11
#  URL:  https://www.amnesty.org/en/latest/campaigns/page/11
# At page 12
#  URL:  https://www.amnesty.org/en/latest/campaigns/page/12
# At page 13
#  URL:  https://www.amnesty.org/en/latest/campaigns/page/13
# At page 14
# ...

# %%
df
# Out:
#                                                 Title      Source  \
# 0   Tunisia: Further Information: Ex-Minister Sent...  AI Hungary
# 0          USA: Alabama’s sixth execution of the year  AI Hungary
# 0         Honduras: Justice for water defender killed  AI Hungary
# 0          Colombia: Women searchers needs protection  AI Hungary
# 0   Why is the Democratic Republic of Congo wracke...  AI Hungary
# ..                                                ...         ...
# 0   Bahrain: Prisoner of conscience convicted and ...  AI Hungary
# 0        Mexico: Rights of feminicide victims at risk  AI Hungary
# 0   Peru: Protesters killed and injured in violent...  AI Hungary
# 0          Act now to demand the release of the BK16!  AI Hungary
# 0                           Amnesty in Africa Podcast  AI Hungary
#
#                                                  Link Excerpt  \
# 0   https://www.amnesty.org/en/documents/mde30/870...    None
# ...

# %%
any(df["PDF"])

# %%
df.to_csv("Hungary.csv")
